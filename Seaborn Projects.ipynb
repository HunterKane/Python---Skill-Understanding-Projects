# %% [markdown]
# # Seaborn
#
# Seaborn is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics.
#
#
# github Seaborn Python:
# https://github.com/seaborn
#
#
# Check this link for further documentation:
# https://seaborn.pydata.org

# %%
import seaborn as sns 
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Different types of visualizations
#
# - Distribution
# - Categorical
# - Matrix
# - Grids
# - Regression Plots

# %% [markdown]
# ### Distribution

# %%
# Load in built in Seaborn dataset 
tips =sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.histplot(tips['total_bill'], kde = False, bins=30);

# %%
sns.kdeplot(tips['total_bill']);

# %% [markdown]
# - Most of the bills are between 10-20 dollars. Fades away the higher the bill price.

# %%
sns.jointplot(x='total_bill', y='tip', data = tips, kind = 'scatter')

# %% [markdown]
# - Higher bill normally means a higher tip due to the bill price is higher. Data shows an upward trend.

# %%
sns.pairplot(tips, hue = 'sex')

# %%
sns.rugplot(tips['total_bill']);

# %% [markdown]
# ### Catigorical

# %%
import numpy as np

# %%
sns.barplot(x='sex',y='total_bill',data=tips,estimator=np.std);

# %%
sns.countplot(x='sex', data=tips);

# %%
sns.boxplot(x='day', y='total_bill', data=tips, hue='smoker');

# %% [markdown]
# - People on fridays tends to have a larger bill who are not smokers.
# - Poeple on Saturday and Sunday are smokers with a larger bill.

# %%
sns.violinplot(x='day', y='total_bill', data=tips, hue='sex', split = True)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x='day', y='total_bill', data=tips,jitter = True, hue='sex', dodge=True);

# %%
sns.swarmplot(x='day',y='total_bill', data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x='day',y='total_bill', data=tips)
sns.swarmplot(x='day',y='total_bill', data=tips, color='black')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.catplot(x='day',y='total_bill', data=tips, kind = 'bar');

# %% [markdown]
# ## Matrix

# %%
tips = sns.load_dataset('tips')
flights = sns.load_dataset('flights')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
tc = tips.corr()

# %%
sns.heatmap(tc, cmap = 'coolwarm',annot = True);

# %%
flights.corr()
# Out:
#                 year  passengers
# year        1.000000    0.921824
# passengers  0.921824    1.000000

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
flights.pivot_table(index='month', columns='year', values='passengers')
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
fp = flights.pivot_table(index='month', columns='year', values='passengers')

# %%
sns.heatmap(fp, cmap = 'coolwarm', linecolor = 'black', linewidth=3);

# %%
sns.clustermap(fp, cmap='coolwarm', standard_scale=1);

# %% [markdown]
# ## Grids

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
g = sns.FacetGrid(data=tips, col='time', row='smoker')
g.map(plt.scatter, 'total_bill', 'tip')

# %% [markdown]
# ## Regression Plots

# %%
sns.lmplot(x= 'total_bill', y= 'tip', data=tips, hue='sex', markers=['o','v'],
          scatter_kws={'s':100});

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, col='day', row='time', hue='sex',
          aspect=0.6, height=8);

# %% [markdown]
# ### Style And Colors

# %%
sns.set_style('ticks')
sns.countplot(y='sex', data=tips)
# Out:
# <AxesSubplot:xlabel='count', ylabel='sex'>

# %%
sns.lmplot(x='total_bill', y='tip', data=tips,hue='sex', palette= 'seismic');
